# %%
import pandas as pd
import re
import datetime as dt

# %%
with open('dataset/WhatsApp Chat with BCT 2081 AB.txt','r',encoding='utf-8') as f:
    data=f.read()

# %%
print(data)
# Out:
# 14/12/24, 10:04 - Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them. Learn more.
# 05/12/24, 17:14 - Aashish created group "BCT 2081 AB"
# 05/12/24, 17:14 - You were added
# 15/12/24, 17:05 - Abinash: https://docs.google.com/forms/d/e/1FAIpQLSdIP8odbwu3AXFDq6QTNSDKYwBkicJacuAT0r8-azhSS--xtQ/viewform
# 15/12/24, 17:06 - Abinash: If anyone is interested in playing football, please fill out this form with your details.
# 15/12/24, 17:25 - +977 986-1569908: FEE ko theory ma potentiometer ko Pani lekhnu parchha ra?
# 15/12/24, 17:25 - +977 986-1569908: lab report*
# 15/12/24, 17:25 - Abinash: Khaiii broo
# 15/12/24, 17:25 - Abinash: Pardaina hola imo
# 15/12/24, 17:25 - Abinash: Ko sanga cha ni last year ko report
# 15/12/24, 17:25 - Abinash: Uuniharulai tha hola
# 15/12/24, 17:26 - +977 986-1569908: kushal Le khicheko thiyo jasto lagyo
# 15/12/24, 17:27 - Abinash: @⁨Kushal Mishra⁩
# ...

# %%
pattern=r"\d{1,2}/\d{1,2}/\d{2,4},\s\d{2}:\d{2}\s-\s"

# %%
message=re.split(pattern,data)[1:]
print(message)
# Out:
# ['Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them. Learn more.\n', 'Aashish created group "BCT 2081 AB"\n', 'You were added\n', 'Abinash: https://docs.google.com/forms/d/e/1FAIpQLSdIP8odbwu3AXFDq6QTNSDKYwBkicJacuAT0r8-azhSS--xtQ/viewform\n', 'Abinash: If anyone is interested in playing football, please fill out this form with your details.\n', '+977 986-1569908: FEE ko theory ma potentiometer ko Pani lekhnu parchha ra?\n', '+977 986-1569908: lab report*\n', 'Abinash: Khaiii broo\n', 'Abinash: Pardaina hola imo\n', 'Abinash: Ko sanga cha ni last year ko report\n', 'Abinash: Uuniharulai tha hola\n', '+977 986-1569908: kushal Le khicheko thiyo jasto lagyo\n', 'Abinash: @\u2068Kushal Mishra\u2069\n', 'Dipendra Parajuli: This message was deleted\n', 'Dipendra Parajuli: Thorai description xa \nLekhdeuna\n', '+977 986-1569908: drawing ko chai kata samma garyeu?\n', 'Dipendra Parajuli: 4.4\n', 'Dipendra Parajuli: 4.6 samma garxu\n', '+
# ...

# %%
date=re.findall(pattern,data)
print(date)
# Out:
# ['14/12/24, 10:04 - ', '05/12/24, 17:14 - ', '05/12/24, 17:14 - ', '15/12/24, 17:05 - ', '15/12/24, 17:06 - ', '15/12/24, 17:25 - ', '15/12/24, 17:25 - ', '15/12/24, 17:25 - ', '15/12/24, 17:25 - ', '15/12/24, 17:25 - ', '15/12/24, 17:25 - ', '15/12/24, 17:26 - ', '15/12/24, 17:27 - ', '15/12/24, 17:30 - ', '15/12/24, 17:30 - ', '15/12/24, 17:31 - ', '15/12/24, 17:31 - ', '15/12/24, 17:31 - ', '15/12/24, 17:31 - ', '15/12/24, 17:32 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/24, 17:33 - ', '15/12/
# ...

# %%
msg_df=pd.DataFrame({'Date':date,'Message':message})

# %%
msg_df.head()
# Out:
#                  Date                                            Message
# 0  14/12/24, 10:04 -   Messages and calls are end-to-end encrypted. O...
# 1  05/12/24, 17:14 -               Aashish created group "BCT 2081 AB"\n
# 2  05/12/24, 17:14 -                                    You were added\n
# 3  15/12/24, 17:05 -   Abinash: https://docs.google.com/forms/d/e/1FA...
# 4  15/12/24, 17:06 -   Abinash: If anyone is interested in playing fo...

# %%
msg_df['Date'] = pd.to_datetime(
    msg_df['Date'],
    format='%d/%m/%y, %H:%M - ',
    errors='coerce'
)

# %%
msg_df.head()
# Out:
#                  Date                                            Message
# 0 2024-12-14 10:04:00  Messages and calls are end-to-end encrypted. O...
# 1 2024-12-05 17:14:00              Aashish created group "BCT 2081 AB"\n
# 2 2024-12-05 17:14:00                                   You were added\n
# 3 2024-12-15 17:05:00  Abinash: https://docs.google.com/forms/d/e/1FA...
# 4 2024-12-15 17:06:00  Abinash: If anyone is interested in playing fo...

# %%
users=[]
messages=[]
for  message_n in msg_df['Message']:
    entry=re.split(r'([\w\W]+?):\s',message_n)
    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[2])
    else:
        users.append('group_notification')
        messages.append(entry[0])
msg_df['Users']=users
msg_df['Message']=messages

# %%
msg_df.head()
# Out:
#                  Date                                            Message  \
# 0 2024-12-14 10:04:00  Messages and calls are end-to-end encrypted. O...
# 1 2024-12-05 17:14:00              Aashish created group "BCT 2081 AB"\n
# 2 2024-12-05 17:14:00                                   You were added\n
# 3 2024-12-15 17:05:00  https://docs.google.com/forms/d/e/1FAIpQLSdIP8...
# 4 2024-12-15 17:06:00  If anyone is interested in playing football, p...
#
#                 Users
# 0  group_notification
# 1  group_notification
# 2  group_notification
# 3             Abinash
# 4             Abinash

# %%
msg_df['Year']=msg_df['Date'].dt.year

# %%
msg_df.head()
# Out:
#                  Date                                            Message  \
# 0 2024-12-14 10:04:00  Messages and calls are end-to-end encrypted. O...
# 1 2024-12-05 17:14:00              Aashish created group "BCT 2081 AB"\n
# 2 2024-12-05 17:14:00                                   You were added\n
# 3 2024-12-15 17:05:00  https://docs.google.com/forms/d/e/1FAIpQLSdIP8...
# 4 2024-12-15 17:06:00  If anyone is interested in playing football, p...
#
#                 Users  Year
# 0  group_notification  2024
# 1  group_notification  2024
# 2  group_notification  2024
# 3             Abinash  2024
# 4             Abinash  2024

# %%
msg_df['Month']=msg_df['Date'].dt.month_name()

# %%
msg_df['Day']=msg_df['Date'].dt.day

# %%
msg_df['Hour']=msg_df['Date'].dt.hour

# %%
msg_df['Minute']=msg_df['Date'].dt.minute

# %%
msg_df['Day_Week']=msg_df['Date'].dt.day_name()

# %%
msg_df['Month_Num']=msg_df['Date'].dt.month

# %%
msg_df.head(30)
# Out:
#                   Date                                            Message  \
# 0  2024-12-14 10:04:00  Messages and calls are end-to-end encrypted. O...
# 1  2024-12-05 17:14:00              Aashish created group "BCT 2081 AB"\n
# 2  2024-12-05 17:14:00                                   You were added\n
# 3  2024-12-15 17:05:00  https://docs.google.com/forms/d/e/1FAIpQLSdIP8...
# 4  2024-12-15 17:06:00  If anyone is interested in playing football, p...
# 5  2024-12-15 17:25:00  FEE ko theory ma potentiometer ko Pani lekhnu ...
# 6  2024-12-15 17:25:00                                      lab report*\n
# 7  2024-12-15 17:25:00                                      Khaiii broo\n
# 8  2024-12-15 17:25:00                                Pardaina hola imo\n
# 9  2024-12-15 17:25:00              Ko sanga cha ni last year ko report\n
# 10 2024-12-15 17:25:00                             Uuniharulai tha hola\n
# 11 2024-12-15 17:26:00             kushal Le khicheko thiyo jasto lagyo\n
# ...

# %%
msg_df['Date'].dt.date
# Out:
# 0       2024-12-14
# 1       2024-12-05
# 2       2024-12-05
# 3       2024-12-15
# 4       2024-12-15
#            ...
# 2189    2026-01-01
# 2190    2026-01-01
# 2191    2026-01-01
# 2192    2026-01-01
# 2193    2026-01-01
# Name: Date, Length: 2194, dtype: object

# %%
busiest_user=msg_df['Users'].value_counts().head(30).index
count=msg_df['Users'].value_counts().head().values

# %%
busiest_user
# Out:
# Index(['Dipendra Parajuli', 'Aayoos Chand Thaquree', 'Nirjal',
#        'Aaditya Raj Uprety', 'Aavash Sapkota', '+977 982-2339211',
#        '+977 981-9013329', '+977 982-7734320', 'Aashish', 'Kushal Mishra',
#        'Abinash', 'Aadarsha Pokhrel', '+977 981-7712881', '+977 974-5841205',
#        'Anamol', '+977 974-4348555', '+977 986-2472828', '+977 976-3681716',
#        '+977 986-6290910', '+977 984-0610649', '+977 981-7979369',
#        '+977 986-1569908', 'group_notification', 'Dulal', '+977 986-2088709',
#        'Abishek Parajuli', 'Bipin', 'Nugaw Shakya', '+977 974-9900628',
#        '+977 981-0237865'],
#       dtype='object', name='Users')

# %%
count
# Out:
# array([418, 241, 163, 132, 114])

# %%
count/msg_df.shape[0]
# Out:
# array([0.1905196 , 0.10984503, 0.07429353, 0.06016408, 0.05195989])

# %%
from collections import Counter

# %%
import re
import emoji
from collections import Counter
from wordcloud import STOPWORDS

NEPALI_STOPWORDS = {
 
 "hai","nai","la","huss","hunxa","hola","haina","lai","xaina","tyo","pani","haru","chai","gara","tei"
}

SYSTEM_WORDS = {
    "media", "omitted", "message", "deleted",
    "joined", "left", "added", "removed",
    "changed", "created", "group"
}

word_list = []
text = ""

for msg in msg_df["Message"]:
    msg = str(msg).lower().strip()

    if "media omitted" in msg:
        continue

    msg = re.sub(r"http\S+", "", msg)

    msg = emoji.replace_emoji(msg, replace="")

    msg = re.sub(r"[^a-zA-Z\u0900-\u097F\s]", "", msg)

    text += msg + " "

words = text.split()

filtered_words = [
    word for word in words
    if (
        word not in STOPWORDS and
        word not in NEPALI_STOPWORDS and
        word not in SYSTEM_WORDS and
        len(word) > 2
    )
]

word_freq = Counter(filtered_words)
word_list = [[word, count] for word, count in word_freq.items()]

# %%
word_list.sort(key=lambda x : x[1],reverse=True)

# %%
word_list
# Out:
# [['class', 51],
#  ['voli', 45],
#  ['dipendra', 38],
#  ['parajuli', 32],
#  ['baje', 32],
#  ['kati', 29],
#  ['bata', 28],
#  ['ani', 28],
#  ['bholi', 28],
#  ['sir', 26],
#  ['fee', 25],
#  ['dost', 23],
#  ['guys', 22],
#  ['lab', 21],
#  ['garnu', 21],
#  ['wala', 20],
#  ['jana', 20],
#  ['timi', 20],
#  ['kun', 20],
#  ['mai', 19],
#  ['aaja', 19],
#  ['report', 18],
#  ['discord', 18],
#  ['edited', 18],
#  ['samma', 17],
#  ['kei', 17],
#  ['vane', 17],
#  ['kta', 17],
#  ['form', 16],
#  ['garne', 16],
#  ['dekhi', 16],
#  ['bida', 16],
#  ['aashish', 15],
#  ['drawing', 15],
#  ['aaba', 15],
#  ['data', 15],
#  ['matra', 15],
#  ['kaile', 15],
#  ['mula', 15],
#  ['bhane', 14],
#  ['time', 14],
#  ['malai', 14],
#  ['aau', 14],
#  ['pathau', 13],
#  ['mero', 13],
#  ['arko', 13],
#  ['physics', 13],
#  ['xau', 13],
#  ['aba', 13],
#  ['question', 13],
#  ['kina', 13],
#  ['hera', 13],
#  ['vayo', 13],
#  ['jasto', 12],
#  ['sathi', 12],
#  ['everyone', 12],
# ...

# %%
emojis=[]
for msg in msg_df['Message']:
    for word in msg.split():
        if emoji.is_emoji(word):
            emojis.extend(word)
emoji_freq=Counter(emojis)  
emoji_list=[[emojim,count] for emojim,count in emoji_freq.items() ]

# %%
emoji_list.sort(key= lambda x : x[1],reverse=True)

# %%
emoji_list[:10]
# Out:
# [['😆', 20],
#  ['😂', 17],
#  ['🤣', 14],
#  ['️', 6],
#  ['🤦', 4],
#  ['\u200d', 4],
#  ['💀', 3],
#  ['😥', 3],
#  ['😔', 3],
#  ['🥲', 3]]

# %%
msg_df.head()
# Out:
#                  Date                                            Message  \
# 0 2024-12-14 10:04:00  Messages and calls are end-to-end encrypted. O...
# 1 2024-12-05 17:14:00              Aashish created group "BCT 2081 AB"\n
# 2 2024-12-05 17:14:00                                   You were added\n
# 3 2024-12-15 17:05:00  https://docs.google.com/forms/d/e/1FAIpQLSdIP8...
# 4 2024-12-15 17:06:00  If anyone is interested in playing football, p...
#
#                 Users  Year     Month  Day  Hour  Minute  Day_Week  Month_Num
# 0  group_notification  2024  December   14    10       4  Saturday         12
# 1  group_notification  2024  December    5    17      14  Thursday         12
# 2  group_notification  2024  December    5    17      14  Thursday         12
# 3             Abinash  2024  December   15    17       5    Sunday         12
# 4             Abinash  2024  December   15    17       6    Sunday         12

# %%
timeline=msg_df.groupby(['Year','Month','Month_Num']).count()['Message'].reset_index()

# %%
timeline.sort_values(by=['Month_Num'],inplace=True)

# %%
timeline
# Out:
#     Year      Month  Month_Num  Message
# 5   2025    January          1      523
# 12  2026    January          1        7
# 4   2025   February          2      413
# 8   2025      March          3      116
# 1   2025      April          4       67
# 9   2025        May          5      341
# 7   2025       June          6      146
# 6   2025       July          7       54
# 2   2025     August          8       56
# 11  2025  September          9       42
# 10  2025   November         11        4
# 3   2025   December         12       24
# 0   2024   December         12      401

# %%
time=[]
for i in range(timeline.shape[0]):
    time.append(timeline['Month'][i]+'-'+str(timeline['Year'][i]))
timeline['time']=time

# %%
timeline
# Out:
#     Year      Month  Month_Num  Message            time
# 0   2024   December         12      401   December-2024
# 1   2025      April          4       67      April-2025
# 2   2025     August          8       56     August-2025
# 3   2025   December         12       24   December-2025
# 4   2025   February          2      413   February-2025
# 5   2025    January          1      523    January-2025
# 6   2025       July          7       54       July-2025
# 7   2025       June          6      146       June-2025
# 8   2025      March          3      116      March-2025
# 9   2025        May          5      341        May-2025
# 10  2025   November         11        4   November-2025
# 11  2025  September          9       42  September-2025
# 12  2026    January          1        7    January-2026

# %%
timeline.sort_values(by=['Year','Month_Num'],inplace=True)

# %%
timeline
# Out:
#     Year      Month  Month_Num  Message            time
# 0   2024   December         12      401   December-2024
# 5   2025    January          1      523    January-2025
# 4   2025   February          2      413   February-2025
# 8   2025      March          3      116      March-2025
# 1   2025      April          4       67      April-2025
# 9   2025        May          5      341        May-2025
# 7   2025       June          6      146       June-2025
# 6   2025       July          7       54       July-2025
# 2   2025     August          8       56     August-2025
# 11  2025  September          9       42  September-2025
# 10  2025   November         11        4   November-2025
# 3   2025   December         12       24   December-2025
# 12  2026    January          1        7    January-2026

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(timeline['time'],timeline['Message'])
plt.xticks(rotation='vertical')
plt.show()

# %%
timeline['time'].tolist()
# Out:
# ['December-2024',
#  'April-2025',
#  'August-2025',
#  'December-2025',
#  'February-2025',
#  'January-2025',
#  'July-2025',
#  'June-2025',
#  'March-2025',
#  'May-2025',
#  'November-2025',
#  'September-2025',
#  'January-2026']

# %%
#Daily Timeline

# %%
tm2=msg_df.groupby(msg_df['Date'].dt.date).count()['Message'].reset_index()

# %%
tm2
# Out:
#            Date  Message
# 0    2024-12-05        2
# 1    2024-12-14        1
# 2    2024-12-15       66
# 3    2024-12-16       51
# 4    2024-12-17        1
# ..          ...      ...
# 149  2025-12-15        4
# 150  2025-12-17        4
# 151  2025-12-18       11
# 152  2025-12-24        3
# 153  2026-01-01        7
#
# [154 rows x 2 columns]

# %%
plt.Figure(figsize=(12,8))
plt.plot(tm2['Date'],tm2['Message'])

# %%
timeline=msg_df.groupby(['Year','Month','Month_Num']).count()['Message'].reset_index()
tm2=msg_df.groupby(msg_df['Date'].dt.date).count()['Message'].reset_index()
time=[]
for i in range(timeline.shape[0]):
    time.append(timeline['Month'][i]+'-'+str(timeline['Year'][i]))

# %%
time
# Out:
# ['December-2024',
#  'April-2025',
#  'August-2025',
#  'December-2025',
#  'February-2025',
#  'January-2025',
#  'July-2025',
#  'June-2025',
#  'March-2025',
#  'May-2025',
#  'November-2025',
#  'September-2025',
#  'January-2026']

# %%
tm2
# Out:
#            Date  Message
# 0    2024-12-05        2
# 1    2024-12-14        1
# 2    2024-12-15       66
# 3    2024-12-16       51
# 4    2024-12-17        1
# ..          ...      ...
# 149  2025-12-15        4
# 150  2025-12-17        4
# 151  2025-12-18       11
# 152  2025-12-24        3
# 153  2026-01-01        7
#
# [154 rows x 2 columns]

# %%
#Time

# %%
msg_df.head()
# Out:
#                  Date                                            Message  \
# 0 2024-12-14 10:04:00  Messages and calls are end-to-end encrypted. O...
# 1 2024-12-05 17:14:00              Aashish created group "BCT 2081 AB"\n
# 2 2024-12-05 17:14:00                                   You were added\n
# 3 2024-12-15 17:05:00  https://docs.google.com/forms/d/e/1FAIpQLSdIP8...
# 4 2024-12-15 17:06:00  If anyone is interested in playing football, p...
#
#                 Users  Year     Month  Day  Hour  Minute  Day_Week  Month_Num
# 0  group_notification  2024  December   14    10       4  Saturday         12
# 1  group_notification  2024  December    5    17      14  Thursday         12
# 2  group_notification  2024  December    5    17      14  Thursday         12
# 3             Abinash  2024  December   15    17       5    Sunday         12
# 4             Abinash  2024  December   15    17       6    Sunday         12

# %%
tm3=msg_df.groupby(msg_df['Date'].dt.hour).count()['Message'].reset_index()

# %%
tm3
# Out:
#     Date  Message
# 0      0       67
# 1      2        1
# 2      6        8
# 3      7       43
# 4      8       48
# 5      9       31
# 6     10       38
# 7     11       49
# 8     12       46
# 9     13       52
# 10    14       90
# 11    15       85
# 12    16      101
# 13    17      161
# 14    18      222
# 15    19      427
# 16    20      198
# 17    21      326
# 18    22      155
# 19    23       46

# %%
step=1
plt.plot(tm3['Date'].astype(str).tolist(),tm3['Message'])
plt.xticks(
    ticks=range(0, len(tm3['Date'].astype(str).tolist()), step),
    labels=[tm3['Date'].astype(str).tolist()[i] for i in range(0, len(tm3['Date'].astype(str).tolist()), step)],
    rotation=45
)
# Out:
# ([<matplotlib.axis.XTick at 0x192a0793890>,
# ...
#  [Text(0, 0, '0'),
#   Text(1, 0, '2'),
#   Text(2, 0, '6'),
#   Text(3, 0, '7'),
#   Text(4, 0, '8'),
#   Text(5, 0, '9'),
#   Text(6, 0, '10'),
#   Text(7, 0, '11'),
#   Text(8, 0, '12'),
#   Text(9, 0, '13'),
#   Text(10, 0, '14'),
#   Text(11, 0, '15'),
#   Text(12, 0, '16'),
#   Text(13, 0, '17'),
#   Text(14, 0, '18'),
#   Text(15, 0, '19'),
#   Text(16, 0, '20'),
#   Text(17, 0, '21'),
#   Text(18, 0, '22'),
#   Text(19, 0, '23')])
